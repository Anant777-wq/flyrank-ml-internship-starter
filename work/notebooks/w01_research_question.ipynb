# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Ranking Signal Analysis
# I chose this lane because I want to focus on Exploratory Data Analysis (EDA) to understand which observable features actually correlate with a page's success before moving on to building predictive models.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# 1. What decision does this improve?
# Deciding which specific content or search signals (e.g., word count, age) to prioritize when creating or updating pages to improve visibility.
#
# 2. Who acts on the output, and what do they do?
# The Content Strategy Team / Editors. They will use this to update their content guidelines and focus their editing efforts on the signals that actually matter.
#
# 3. What does a wrong answer cost?
# Wasted editor hours chasing signals that don't actually improve visibility, leading to stagnant traffic and wasted budget.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# Print out how many rows (pages) and columns we have to analyze
print(f"I have {df.shape[0]} pages and {df.shape[1]} metrics to analyze for my signals!")
# Out:
# I have 30000 pages and 44 metrics to analyze for my signals!

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can and cannot claim:
# My work will provide observed, directional, and decision-support findings based on correlations in the historical data. Because this is an observational analysis, it will never claim causal proof (e.g., "doing X causes Y") and will never claim to "predict Google's algorithm."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
